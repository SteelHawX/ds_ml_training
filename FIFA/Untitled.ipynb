# %%
import pandas as pd

df = pd.read_csv("dataSets/meanPositionDifference.csv", index_col=0)

# %%
df.head()
# Out:
#           LS        ST        RS        LW        LF        CF        RF  \
# LS  0.710145  0.710145  0.710145  2.787440  1.657005  1.657005  1.657005
# ST  0.291357  0.291357  0.291357  3.092937  1.749071  1.749071  1.749071
# RS  0.679803  0.679803  0.679803  2.950739  1.788177  1.788177  1.788177
# LW  3.493438  3.493438  3.493438  0.288714  1.272966  1.272966  1.272966
# LF  3.866667  3.866667  3.866667  0.600000  1.133333  1.133333  1.133333
#
#           RW       LAM       CAM  ...        LWB        LDM        CDM  \
# LS  2.787440  3.516908  3.516908  ...  17.913043  19.661836  19.661836
# ST  3.092937  3.836431  3.836431  ...  18.044145  19.836896  19.836896
# RS  2.950739  3.748768  3.748768  ...  17.738916  19.551724  19.551724
# LW  0.288714  1.606299  1.606299  ...  13.149606  16.850394  16.850394
# LF  0.600000  0.666667  0.666667  ...  14.666667  16.866667  16.866667
#
#           RDM        RWB         LB        LCB         CB        RCB  \
# ...

# %%
df.index.name = 'Best position'

# %%
df.head()
# Out:
#                      LS        ST        RS        LW        LF        CF  \
# Best position
# LS             0.710145  0.710145  0.710145  2.787440  1.657005  1.657005
# ST             0.291357  0.291357  0.291357  3.092937  1.749071  1.749071
# RS             0.679803  0.679803  0.679803  2.950739  1.788177  1.788177
# LW             3.493438  3.493438  3.493438  0.288714  1.272966  1.272966
# LF             3.866667  3.866667  3.866667  0.600000  1.133333  1.133333
#
#                      RF        RW       LAM       CAM  ...        LWB  \
# Best position                                          ...
# LS             1.657005  2.787440  3.516908  3.516908  ...  17.913043
# ST             1.749071  3.092937  3.836431  3.836431  ...  18.044145
# RS             1.788177  2.950739  3.748768  3.748768  ...  17.738916
# LW             1.272966  0.288714  1.606299  1.606299  ...  13.149606
# LF             1.133333  0.600000  0.666667  0.666667  ...  14.666667
#
# ...

# %%
df = df*-1
df_left = df.transpose()[['LW','LF','LM', 'LWB', 'LB']]
df_left.plot()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
plt.plot(df_left)
plt.legend(('LW','LF','LM', 'LWB', 'LB'), loc='upper left')
